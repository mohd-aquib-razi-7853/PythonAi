# %%
import pandas as pd
import numpy as np

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from sklearn.datasets import fetch_openml

# %%
boston = fetch_openml(name="boston", version=1)

# %%
type(boston)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(boston)
# Out:
# {'data':         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
#pandas dataframe 
boston_df = pd.read_csv("boston.csv")

# %%
boston_df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX  \
# 0             0             0           0  0.00632  18.0   2.31     0  0.538
# 1             1             1           1  0.02731   0.0   7.07     0  0.469
# 2             2             2           2  0.02729   0.0   7.07     0  0.469
# 3             3             3           3  0.03237   0.0   2.18     0  0.458
# 4             4             4           4  0.06905   0.0   2.18     0  0.458
#
#       RM   AGE     DIS  RAD    TAX  PTRATIO       B  LSTAT
# 0  6.575  65.2  4.0900    1  296.0     15.3  396.90   4.98
# 1  6.421  78.9  4.9671    2  242.0     17.8  396.90   9.14
# 2  7.185  61.1  4.9671    2  242.0     17.8  392.83   4.03
# 3  6.998  45.8  6.0622    3  222.0     18.7  394.63   2.94
# 4  7.147  54.2  6.0622    3  222.0     18.7  396.90   5.33

# %%
type(boston_df)
# Out:
# pandas.core.frame.DataFrame

# %%
boston_df.shape
# Out:
# (506, 16)

# %% [raw]
# Importing dataset from CSV

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (768, 9)

# %%
boston_df.to_csv("boston.csv")

# %%
random_df = pd.DataFrame(np.random.rand(40,30))

# %%
random_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.433996  0.572716  0.403990  0.189544  0.109812  0.264652  0.934858
# 1  0.242064  0.100350  0.937430  0.000977  0.337249  0.170727  0.977435
# 2  0.599082  0.285491  0.600676  0.636360  0.787693  0.180663  0.089805
# 3  0.303694  0.979351  0.145363  0.899352  0.667288  0.781790  0.159259
# 4  0.721934  0.036013  0.942465  0.453888  0.892921  0.619631  0.696982
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.597994  0.220936  0.936836  ...  0.236660  0.736939  0.473605  0.773916
# 1  0.753104  0.580792  0.507479  ...  0.568529  0.029229  0.490165  0.252368
# 2  0.108928  0.782275  0.618718  ...  0.890146  0.628641  0.896883  0.942140
# 3  0.815499  0.065821  0.680969  ...  0.255612  0.984026  0.174694  0.341159
# 4  0.387684  0.428945  0.933044  ...  0.350186  0.528756  0.717630  0.630908
#
#          24        25        26        27        28        29
# ...

# %%
# dataframe infomation 
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  506 non-null    int64
#  1   Unnamed: 0.1  506 non-null    int64
#  2   Unnamed: 0    506 non-null    int64
#  3   CRIM          506 non-null    float64
#  4   ZN            506 non-null    float64
#  5   INDUS         506 non-null    float64
#  6   CHAS          506 non-null    int64
#  7   NOX           506 non-null    float64
#  8   RM            506 non-null    float64
#  9   AGE           506 non-null    float64
#  10  DIS           506 non-null    float64
#  11  RAD           506 non-null    int64
#  12  TAX           506 non-null    float64
#  13  PTRATIO       506 non-null    float64
#  14  B             506 non-null    float64
#  15  LSTAT         506 non-null    float64
# dtypes: float64(11), int64(5)
# memory usage: 63.4 KB

# %%
# finding the missing value 
boston_df.isnull().sum()
# Out:
# Unnamed: 0.2    0
# Unnamed: 0.1    0
# Unnamed: 0      0
# CRIM            0
# ZN              0
# INDUS           0
# CHAS            0
# NOX             0
# RM              0
# AGE             0
# DIS             0
# RAD             0
# TAX             0
# PTRATIO         0
# B               0
# LSTAT           0
# dtype: int64

# %%
# diabetes dataFrame 
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.value_counts("Outcome")
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#grouping the value by their mean 
df.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#count the no of value 
boston_df.count()
# Out:
# Unnamed: 0.2    506
# Unnamed: 0.1    506
# Unnamed: 0      506
# CRIM            506
# ZN              506
# INDUS           506
# CHAS            506
# NOX             506
# RM              506
# AGE             506
# DIS             506
# RAD             506
# TAX             506
# PTRATIO         506
# B               506
# LSTAT           506
# dtype: int64

# %%
# mean value - column wise
boston_df.mean()
# Out:
# Unnamed: 0.2    252.500000
# Unnamed: 0.1    252.500000
# Unnamed: 0      252.500000
# CRIM              3.613524
# ZN               11.363636
# INDUS            11.136779
# CHAS              0.069170
# NOX               0.554695
# RM                6.284634
# AGE              68.574901
# DIS               3.795043
# RAD               9.549407
# TAX             408.237154
# PTRATIO          18.455534
# B               356.674032
# LSTAT            12.653063
# dtype: float64

# %%
# standard Deviation 
boston_df.std()
# Out:
# Unnamed: 0.2    146.213884
# Unnamed: 0.1    146.213884
# Unnamed: 0      146.213884
# CRIM              8.601545
# ZN               23.322453
# INDUS             6.860353
# CHAS              0.253994
# NOX               0.115878
# RM                0.702617
# AGE              28.148861
# DIS               2.105710
# RAD               8.707259
# TAX             168.537116
# PTRATIO           2.164946
# B                91.294864
# LSTAT             7.141062
# dtype: float64

# %%
boston_df.min()
# Out:
# Unnamed: 0.2      0.00000
# Unnamed: 0.1      0.00000
# Unnamed: 0        0.00000
# CRIM              0.00632
# ZN                0.00000
# INDUS             0.46000
# CHAS              0.00000
# NOX               0.38500
# RM                3.56100
# AGE               2.90000
# DIS               1.12960
# RAD               1.00000
# TAX             187.00000
# PTRATIO          12.60000
# B                 0.32000
# LSTAT             1.73000
# dtype: float64

# %%
# max value column wise
boston_df.max()
# Out:
# Unnamed: 0.2    505.0000
# Unnamed: 0.1    505.0000
# Unnamed: 0      505.0000
# CRIM             88.9762
# ZN              100.0000
# INDUS            27.7400
# CHAS              1.0000
# NOX               0.8710
# RM                8.7800
# AGE             100.0000
# DIS              12.1265
# RAD              24.0000
# TAX             711.0000
# PTRATIO          22.0000
# B               396.9000
# LSTAT            37.9700
# dtype: float64

# %%
boston_df.describe()
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        CRIM          ZN  \
# count    506.000000    506.000000  506.000000  506.000000  506.000000
# mean     252.500000    252.500000  252.500000    3.613524   11.363636
# std      146.213884    146.213884  146.213884    8.601545   23.322453
# min        0.000000      0.000000    0.000000    0.006320    0.000000
# 25%      126.250000    126.250000  126.250000    0.082045    0.000000
# 50%      252.500000    252.500000  252.500000    0.256510    0.000000
# 75%      378.750000    378.750000  378.750000    3.677083   12.500000
# max      505.000000    505.000000  505.000000   88.976200  100.000000
#
#             INDUS        CHAS         NOX          RM         AGE         DIS  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    11.136779    0.069170    0.554695    6.284634   68.574901    3.795043
# std      6.860353    0.253994    0.115878    0.702617   28.148861    2.105710
# ...

# %%
#adding the column to a dataFrame
boston_df["Price"] = boston.target

# %%
boston_df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX  \
# 0             0             0           0  0.00632  18.0   2.31     0  0.538
# 1             1             1           1  0.02731   0.0   7.07     0  0.469
# 2             2             2           2  0.02729   0.0   7.07     0  0.469
# 3             3             3           3  0.03237   0.0   2.18     0  0.458
# 4             4             4           4  0.06905   0.0   2.18     0  0.458
#
#       RM   AGE     DIS  RAD    TAX  PTRATIO       B  LSTAT  Price
# 0  6.575  65.2  4.0900    1  296.0     15.3  396.90   4.98   24.0
# 1  6.421  78.9  4.9671    2  242.0     17.8  396.90   9.14   21.6
# 2  7.185  61.1  4.9671    2  242.0     17.8  392.83   4.03   34.7
# 3  6.998  45.8  6.0622    3  222.0     18.7  394.63   2.94   33.4
# 4  7.147  54.2  6.0622    3  222.0     18.7  396.90   5.33   36.2

# %%
#remove the row from the datasets
boston_df.drop(index=0, axis=0)
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     CRIM   ZN  INDUS  CHAS    NOX  \
# 1               1             1           1  0.02731  0.0   7.07     0  0.469
# 2               2             2           2  0.02729  0.0   7.07     0  0.469
# 3               3             3           3  0.03237  0.0   2.18     0  0.458
# 4               4             4           4  0.06905  0.0   2.18     0  0.458
# 5               5             5           5  0.02985  0.0   2.18     0  0.458
# ..            ...           ...         ...      ...  ...    ...   ...    ...
# 501           501           501         501  0.06263  0.0  11.93     0  0.573
# 502           502           502         502  0.04527  0.0  11.93     0  0.573
# 503           503           503         503  0.06076  0.0  11.93     0  0.573
# 504           504           504         504  0.10959  0.0  11.93     0  0.573
# 505           505           505         505  0.04741  0.0  11.93     0  0.573
#
# ...

# %%
boston_df.drop(columns='ZN', axis=1)
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     CRIM  INDUS  CHAS    NOX  \
# 0               0             0           0  0.00632   2.31     0  0.538
# 1               1             1           1  0.02731   7.07     0  0.469
# 2               2             2           2  0.02729   7.07     0  0.469
# 3               3             3           3  0.03237   2.18     0  0.458
# 4               4             4           4  0.06905   2.18     0  0.458
# ..            ...           ...         ...      ...    ...   ...    ...
# 501           501           501         501  0.06263  11.93     0  0.573
# 502           502           502         502  0.04527  11.93     0  0.573
# 503           503           503         503  0.06076  11.93     0  0.573
# 504           504           504         504  0.10959  11.93     0  0.573
# 505           505           505         505  0.04741  11.93     0  0.573
#
#         RM   AGE     DIS  RAD    TAX  PTRATIO       B  LSTAT  Price
# ...

# %%
boston_df.drop(columns='Unnamed: 0.1')
# Out:
#      Unnamed: 0.2  Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE  \
# 0               0           0  0.00632  18.0   2.31     0  0.538  6.575  65.2
# 1               1           1  0.02731   0.0   7.07     0  0.469  6.421  78.9
# 2               2           2  0.02729   0.0   7.07     0  0.469  7.185  61.1
# 3               3           3  0.03237   0.0   2.18     0  0.458  6.998  45.8
# 4               4           4  0.06905   0.0   2.18     0  0.458  7.147  54.2
# ..            ...         ...      ...   ...    ...   ...    ...    ...   ...
# 501           501         501  0.06263   0.0  11.93     0  0.573  6.593  69.1
# 502           502         502  0.04527   0.0  11.93     0  0.573  6.120  76.7
# 503           503         503  0.06076   0.0  11.93     0  0.573  6.976  91.0
# 504           504         504  0.10959   0.0  11.93     0  0.573  6.794  89.3
# 505           505         505  0.04741   0.0  11.93     0  0.573  6.030  80.8
#
# ...

# %%
boston_df.drop(columns='Unnamed: 0')
# Out:
#      Unnamed: 0.2  Unnamed: 0.1     CRIM    ZN  INDUS  CHAS    NOX     RM  \
# 0               0             0  0.00632  18.0   2.31     0  0.538  6.575
# 1               1             1  0.02731   0.0   7.07     0  0.469  6.421
# 2               2             2  0.02729   0.0   7.07     0  0.469  7.185
# 3               3             3  0.03237   0.0   2.18     0  0.458  6.998
# 4               4             4  0.06905   0.0   2.18     0  0.458  7.147
# ..            ...           ...      ...   ...    ...   ...    ...    ...
# 501           501           501  0.06263   0.0  11.93     0  0.573  6.593
# 502           502           502  0.04527   0.0  11.93     0  0.573  6.120
# 503           503           503  0.06076   0.0  11.93     0  0.573  6.976
# 504           504           504  0.10959   0.0  11.93     0  0.573  6.794
# 505           505           505  0.04741   0.0  11.93     0  0.573  6.030
#
#       AGE     DIS  RAD    TAX  PTRATIO       B  LSTAT  Price
# ...

# %%
boston_df = boston_df.drop(columns='Unnamed: 0')

# %%
boston_df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE  \
# 0             0             0  0.00632  18.0   2.31     0  0.538  6.575  65.2
# 1             1             1  0.02731   0.0   7.07     0  0.469  6.421  78.9
# 2             2             2  0.02729   0.0   7.07     0  0.469  7.185  61.1
# 3             3             3  0.03237   0.0   2.18     0  0.458  6.998  45.8
# 4             4             4  0.06905   0.0   2.18     0  0.458  7.147  54.2
#
#       DIS  RAD    TAX  PTRATIO       B  LSTAT  Price
# 0  4.0900    1  296.0     15.3  396.90   4.98   24.0
# 1  4.9671    2  242.0     17.8  396.90   9.14   21.6
# 2  4.9671    2  242.0     17.8  392.83   4.03   34.7
# 3  6.0622    3  222.0     18.7  394.63   2.94   33.4
# 4  6.0622    3  222.0     18.7  396.90   5.33   36.2

# %%
boston_df = boston_df.drop(columns='Unnamed: 0.2')

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
# 
print(boston_df.iloc[:,0])
print(boston_df.iloc[:,-1])
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: Price, Length: 506, dtype: float64

# %% [raw]
# Corelation :
# 1. Positive corelation
# 2. Negative corelation

# %%
boston_df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...
